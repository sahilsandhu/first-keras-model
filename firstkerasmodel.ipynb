# %%
import pandas as pd

# %%
data=pd.read_csv("/home/jovyan/demo/ionosphere_data_kaggle.csv")
print(data.head())
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# ...

# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow.keras 
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
# Out:
# 1.13.1

# %%
x,y=data.values[:,:-1],data.values[:,-1]
y=LabelEncoder().fit_transform(y)
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size= 0.33)
print(xtrain.shape,ytrain.shape,xtest.shape,ytest.shape)
# Out:
# (235, 34) (235,) (116, 34) (116,)

# %%
x=x.astype(float)
n=xtrain.shape[1]
model=Sequential()
model.add(Dense(8,activation='relu',kernel_initializer='he_normal',input_shape=(n,)))
model.add(Dense(5,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(xtrain,ytrain,epochs=120,batch_size=32,verbose=2)
# Out:
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/120
#  - 0s - loss: 0.6789 - acc: 0.6681
# Epoch 2/120
#  - 0s - loss: 0.6518 - acc: 0.6723
# Epoch 3/120
#  - 0s - loss: 0.6319 - acc: 0.6851
# Epoch 4/120
#  - 0s - loss: 0.6173 - acc: 0.6851
# Epoch 5/120
#  - 0s - loss: 0.6051 - acc: 0.6894
# Epoch 6/120
#  - 0s - loss: 0.5931 - acc: 0.6936
# Epoch 7/120
#  - 0s - loss: 0.5832 - acc: 0.6979
# Epoch 8/120
#  - 0s - loss: 0.5733 - acc: 0.7021
# Epoch 9/120
#  - 0s - loss: 0.5639 - acc: 0.7064
# Epoch 10/120
#  - 0s - loss: 0.5545 - acc: 0.7149
# Epoch 11/120
#  - 0s - loss: 0.5450 - acc: 0.7277
# Epoch 12/120
#  - 0s - loss: 0.5360 - acc: 0.7319
# Epoch 13/120
#  - 0s - loss: 0.5269 - acc: 0.7574
# Epoch 14/120
#  - 0s - loss: 0.5177 - acc: 0.7660
# ...

# %%
loss,acc=model.evaluate(xtest,ytest,verbose=2)
# Out:
#  - 0s - loss: 0.2165 - acc: 0.9224
